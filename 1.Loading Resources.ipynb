# %% [markdown]
# !pip install indeterminatebeam

# %%
from indeterminatebeam import Beam, Support

from indeterminatebeam import (
    PointTorque,
    PointLoad,
    PointLoadV,
    PointLoadH,
    UDL,
    UDLV,
    UDLH,
    TrapezoidalLoad,
    TrapezoidalLoadV,
    TrapezoidalLoadH,
    DistributedLoad,
    DistributedLoadV,
    DistributedLoadH
)

"""

At the end of load:

H --> Horizontal Loads
V --> Vertical Loads
nan --> Takes angle as input 

"""

print('Import Successful !')
# Out:
# Import Successful !
